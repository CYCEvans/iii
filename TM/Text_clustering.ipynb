# %%
import json
import time
from itertools import cycle

import gensim
import jieba
import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn import manifold
from sklearn.cluster import KMeans, AgglomerativeClustering, MeanShift, estimate_bandwidth, Birch
from sklearn import decomposition
from sklearn.neighbors import kneighbors_graph
import matplotlib.colors as colors
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
stop_word_set = set()
with open(r'./stopwords.txt', 'r', encoding='utf-8') as sw:
    for line in sw:
        stop_word_set.add(line.strip('\n'))

# %%
with open("content.json") as f:
    data_dict=json.load(f)

# %%
data = data_dict["content"]

# %%
data[88]
# Out:
# '租 三房兩廳 電梯 華廈 簽約 押金 月 搬來 時 一對二 分離式 冷氣 簽約 時 已 告知 房東 會帶 冷氣 家電 房東 允諾 移除 原本 屋子 裡的 窗型 冷氣 並未 告知 這項 費用 房客 自行 支付 住 五個 月 之後 實在 接受 房東 處理 問題 態度 八八 水災 窗台 滲水 當面 告知 房東 得到 答覆 之後 一陣 安靜 只好 花錢 買 來處 裡 再 每月 收 元 管理費 每次 包裹 寄來 樓下 一位 只上 白班 中午 睡個 午覺 再 出現 管理員 下樓 配送 人員 領取 包裹 理由 管理員 負責 代收 工作 之後 發生 誇張 事情 管理員 房東太太 擔任 身兼 管理員 房東太太 翻閱 我訂 報紙 撞見 拿回 住所 閱讀 人 傻眼 行徑 不及 備載 最後 受不了 租屋 委曲 不便 打算 搬回 家 提前 解約 打算 賠 一個月 違約金 房東 卻說 搬進來 拆裝 冷氣 費用 支付 元 契約 損失 賠償 說 留置權 不准 提前 搬走 這讓 困擾 想 版上 我該 只 打算 租到 月底 預計 搬走 是不是 認賠 月 押金 房東 討 順利 搬走 好 應對 方法 擔心 妨礙 搬家 月 房租 我繳 積欠 房租 月 押金 房東 手上 留置權 可用'

# %%
Lsent = gensim.models.doc2vec.LabeledSentence
def labelizeNews(News, label_type):
    labelized = []
    #enumertate include index
    for i, v in enumerate(News):
        label = '%s_%s' %(label_type,i)
        labelized.append(Lsent(v, [label]))
    return labelized

# %%
size = 400   
model_dm = gensim.models.Doc2Vec(min_count=1, window=10, size=size, sample=1e-3, negative=5, workers=3)
model_dbow = gensim.models.Doc2Vec(min_count=1, window=10, size=size, sample=1e-3, negative=5,dm=0, workers=3)
train = labelizeNews(data,'train')
model_dm.build_vocab(train)
model_dbow.build_vocab(train)

# %%
for epoch in range(10):
    perm = np.random.permutation(len(train))
    model_dm.train([train[x] for x in perm], total_examples=model_dm.corpus_count, epochs=model_dm.iter)
    model_dbow.train([train[x] for x in perm], total_examples=model_dbow.corpus_count, epochs=model_dbow.iter)

# %%
model_dm.save(r'model_dm')
model_dbow.save(r'model_dbow')

# %%
# model_dm = model_dm.load(r'model_dm')
# model_dbow =model_dbow.load(r'model_dbow')

# %%
def getVecs(model, corpus, size):
    vecs = [model.docvecs[z.tags[0]].reshape((1, size)) for z in corpus]
    return np.concatenate(vecs)

# %%
Train_vecs_dm = getVecs(model_dm, train, size)
Train_vecs_dbow = getVecs(model_dbow, train, size)
train_vecs = np.hstack((Train_vecs_dm, Train_vecs_dbow))

# %%
train_vecs
# Out:
# array([[-0.02709793, -1.0312444 ,  0.68631762, ..., -0.0943526 ,
#         -0.389182  , -0.06664371],
#        [ 0.57394457,  0.05197258,  0.15993632, ..., -0.32270473,
#         -0.04560512,  0.09722729],
#        [ 0.474839  , -1.27452207,  0.43719471, ..., -0.13309295,
#          0.21394458, -0.49603042],
#        ...,
#        [ 1.40113676,  0.1449578 , -0.54904103, ...,  0.2228324 ,
#         -0.21458665,  0.24942026],
#        [-0.25704819, -0.63572091,  0.05757908, ..., -0.07477729,
#          0.3096326 , -0.30294487],
#        [-0.20772088, -0.30012271,  1.78502464, ..., -0.22249563,
#         -0.05643746, -0.02676174]], dtype=float32)

# %%
#固定random state 隨機初始值 fixed the seed
All_kmeans = KMeans(n_clusters=5, random_state=0).fit(train_vecs)

# %%
distortions = []
sup = 9
for i in range(1, sup):
    km = KMeans(n_clusters=i, 
                init='k-means++', 
                n_init=10, 
                max_iter=300, 
                random_state=0)
    km.fit(train_vecs)
    distortions.append(km.inertia_)
plt.plot(range(1, sup), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.tight_layout()
plt.show()

# %%
kmean_7 = KMeans(n_clusters=7, random_state=0).fit(train_vecs)

# %%
X= pd.read_csv('./data_lable.csv')

# %%
X.insert(0, "Cluster", All_kmeans.labels_)

# %%
len(train_vecs)
# Out:
# 4417

# %%
X.head()
# Out:
#    Cluster  Unnamed: 0                     lable                       _id  \
# 0        1           0  {'環境問題', '合約問題', '租金問題'}  599aac7faadaed95a0f57f5b
# 1        2           1          {'合約問題', '租金問題'}  599aac7faadaed95a0f57f5d
# 2        2           2            {'糾紛', '租金問題'}  599aac7faadaed95a0f57f5e
# 3        1           3          {'環境問題', '租金問題'}  599aac7faadaed95a0f57f5f
# 4        1           4                  {'環境問題'}  599aac7faadaed95a0f57f61
#
#            article_id      author     board  \
# 0  M.1255571810.A.474     m330jjj  rent-exp
# 1  M.1255587087.A.575    parkview  rent-exp
# 2  M.1255611415.A.1F3       jusie  rent-exp
# 3  M.1255615113.A.FCC  dondon0419  rent-exp
# 4  M.1255617703.A.A44        oarp  rent-exp
#
#                                             comments  \
# 0  [{'push_content': ':請他找到人頂替 不然不退11月的錢', 'push_...
# 1  [{'push_content': ':合約都簽了就照合約走 出去的錢應該回不來', 'pu...
# 2  [{'push_content': ':他的詩肯柚木椅很新嗎？如果是舊的、原本就有刮痕，那要...
# 3  [{'push_content': ':找長輩或朋友陪你去談，比較安全哦', 'push_i...
# 4  [{'push_content': ':可參考DEATH NOTE', 'push_ipda...
#
#                                       comments_count  \
# 0  {'total_count': 5, 'boo': 0, 'push': 1, 'neutr...
# 1  {'total_count': 11, 'boo': 0, 'push': 3, 'neut...
# 2  {'total_count': 9, 'boo': 0, 'push': 4, 'neutr...
# 3  {'total_count': 2, 'boo': 0, 'push': 2, 'neutr...
# 4  {'total_count': 21, 'boo': 0, 'push': 6, 'neut...
#
#                                              content        date   ip  rate  \
# 0  ───────────────────────────────────────我的情況是這樣...  2009-10-15  NaN     1
# 1  這是我學妹發生的問題 事情是這樣的我一個大一學妹租了我隔壁的一間單人套房房租一個月一萬 押金...  2009-10-15  NaN     3
# 2  板上的大家好:    預計十月底搬走,    十月的房租已付清,    十月十一日告知房東,...  2009-10-15  NaN     4
# 3  我7月1號搬出舊的地方然後因為還要扣水電所以押金就沒有拿結果拖到今天我忍不住打電話去問他居然...  2009-10-15  NaN     2
# 4  住進目前的房子已經快一個月了~~期間有幾次有意無意的知道房東曾經未告知就進過我的房間例如 房...  2009-10-15  NaN     6
#
#                     title                                                url
# 0             [金錢] 我該怎麼做?  https://www.ptt.cc/bbs/rent-exp/M.1255571810.A...
# 1  [金錢] 合約簽了還沒住進去房租應該被扣嗎?  https://www.ptt.cc/bbs/rent-exp/M.1255587087.A...
# 2       [金錢] 房東不退押金 我該怎麼辦  https://www.ptt.cc/bbs/rent-exp/M.1255611415.A...
# 3              [金錢] 誇張的房東  https://www.ptt.cc/bbs/rent-exp/M.1255615113.A...
# 4      [房東] 想測試房東到底有沒有進來過  https://www.ptt.cc/bbs/rent-exp/M.1255617703.A...

# %%
X['lable']
# Out:
# 0       {'環境問題', '合約問題', '租金問題'}
# 1               {'合約問題', '租金問題'}
# 2                 {'糾紛', '租金問題'}
# 3               {'環境問題', '租金問題'}
# 4                       {'環境問題'}
# 5                       {'租金問題'}
# 6               {'環境問題', '租金問題'}
# 7                       {'租金問題'}
# 8                       {'租金問題'}
# 9                       {'租金問題'}
# 10              {'房屋問題', '租金問題'}
# 11              {'房屋問題', '租金問題'}
# 12                      {'租金問題'}
# 13                        {None}
# 14                      {'租金問題'}
# 15                      {'環境問題'}
# 16                      {'租金問題'}
# 17              {'合約問題', '租金問題'}
# 18              {'環境問題', '租金問題'}
# 19                        {None}
# 20              {'房屋問題', '租金問題'}
# 21                      {'租金問題'}
# 22                        {None}
# 23                      {'合約問題'}
# 24                        {None}
# 25                      {'合約問題'}
# 26                        {None}
# 27                      {'合約問題'}
# 28                      {'合約問題'}
# 29              {'合約問題', '租金問題'}
#                   ...
# 4387                    {'租金問題'}
# 4388      {'治安', '合約問題', '租金問題'}
# 4389                    {'租金問題'}
# 4390            {'合約問題', '租金問題'}
# 4391                      {None}
# 4392                    {'租金問題'}
# 4393                    {'環境問題'}
# 4394                      {'糾紛'}
# 4395                    {'租金問題'}
# 4396                      {None}
# 4397            {'房屋問題', '租金問題'}
# 4398            {'房屋問題', '租金問題'}
# 4399            {'環境問題', '合約問題'}
# 4400                      {None}
# 4401            {'合約問題', '租金問題'}
# 4402                      {None}
# 4403            {'合約問題', '租金問題'}
# 4404                    {'租金問題'}
# 4405                    {'租金問題'}
# 4406      {'糾紛', '合約問題', '租金問題'}
# 4407                    {'合約問題'}
# 4408            {'合約問題', '租金問題'}
# 4409                    {'合約問題'}
# 4410                    {'租金問題'}
# 4411                    {'租金問題'}
# 4412            {'合約問題', '租金問題'}
# 4413            {'房屋問題', '合約問題'}
# 4414      {'糾紛', '合約問題', '租金問題'}
# 4415                    {'房屋問題'}
# 4416              {'糾紛', '租金問題'}
# Name: lable, dtype: object

# %%
X['lable'].value_counts()
# Out:
# {None}                                  1083
# {'租金問題'}                                 694
# {'合約問題', '租金問題'}                         610
# {'合約問題'}                                 575
# {'房屋問題'}                                 253
# {'環境問題'}                                 177
# {'房屋問題', '租金問題'}                         124
# {'環境問題', '租金問題'}                         103
# {'環境問題', '合約問題'}                          77
# {'房屋問題', '合約問題'}                          65
# {'環境問題', '合約問題', '租金問題'}                  64
# {'糾紛'}                                    64
# {'糾紛', '合約問題', '租金問題'}                    60
# {'房屋問題', '合約問題', '租金問題'}                  54
# {'糾紛', '合約問題'}                            52
# {'糾紛', '租金問題'}                            42
# {'治安'}                                    33
# {'環境問題', '房屋問題'}                          31
# {'稅務問題', '合約問題'}                          23
# {'稅務問題', '合約問題', '租金問題'}                  21
# {'稅務問題'}                                  18
# {'房屋問題', '糾紛'}                            13
# {'環境問題', '糾紛'}                            13
# {'環境問題', '房屋問題', '租金問題'}                  12
# {'稅務問題', '租金問題'}                          11
# {'環境問題', '房屋問題', '合約問題', '租金問題'}           8
# {'環境問題', '房屋問題', '合約問題'}                   8
# {'合約問題', '治安'}                             8
# {'糾紛', '治安'}                               8
# {'環境問題', '合約問題', '房屋問題'}                   8
#                                         ...
# {'稅務問題', '糾紛', '合約問題'}                     5
# {'環境問題', '糾紛', '合約問題'}                     5
# {'環境問題', '房屋問題', '糾紛'}                     5
# {'糾紛', '租金問題', '房屋問題'}                     4
# {'環境問題', '糾紛', '租金問題'}                     3
# {'糾紛', '環境問題', '合約問題', '租金問題'}             3
# {'房屋問題', '治安'}                             3
# {'糾紛', '合約問題', '租金問題', '稅務問題'}             3
# {'環境問題', '合約問題', '糾紛'}                     2
# {'稅務問題', '糾紛', '租金問題'}                     2
# {'稅務問題', '環境問題', '合約問題'}                   2
# {'租金問題', '合約問題', '治安'}                     2
# {'環境問題', '租金問題', '糾紛'}                     2
# {'租金問題', '治安'}                             2
# {'糾紛', '環境問題', '房屋問題', '合約問題'}             2
# {'治安', '房屋問題', '租金問題'}                     1
# {'糾紛', '環境問題', '合約問題', '治安', '租金問題'}       1
# {'糾紛', '房屋問題', '合約問題', '治安', '租金問題'}       1
# {'糾紛', '環境問題', '合約問題', '治安'}               1
# {'稅務問題', '房屋問題', '環境問題'}                   1
# {'環境問題', '房屋問題', '合約問題', '治安'}             1
# {'治安', '合約問題', '租金問題'}                     1
# {'房屋問題', '租金問題', '治安'}                     1
# {'治安', '糾紛', '租金問題'}                       1
# {'稅務問題', '房屋問題', '租金問題'}                   1
# {'糾紛', '合約問題', '房屋問題'}                     1
# {'稅務問題', '環境問題'}                           1
# {'房屋問題', '合約問題', '治安'}                     1
# {'環境問題', '合約問題', '治安'}                     1
# {'稅務問題', '房屋問題', '合約問題'}                   1
# Name: lable, dtype: int64

# %%
X['Cluster'].value_counts() #number of films per cluster (clusters from 0 to 4)
# Out:
# 2    2096
# 1     948
# 0     797
# 4     573
# 3       3
# Name: Cluster, dtype: int64

# %%
grouped = X["lable"].groupby(X['Cluster'])

# %%
grouped.all()
# Out:
# Cluster
# 0          {'合約問題', '租金問題'}
# 1                  {'房屋問題'}
# 2    {'糾紛', '合約問題', '租金問題'}
# 3              {'糾紛', '治安'}
# 4            {'糾紛', '租金問題'}
# Name: lable, dtype: object

# %%
def clusterplot(plot_X,labels):
    plotting_X = pd.DataFrame(plot_X,columns=['x','y'])
    n_cluster = len(np.unique(labels))
    colors = ['r', 'b', 'g', 'c', 'm', 'y']
    for l, c in zip(range(n_cluster), colors):
        plt.scatter(plotting_X[labels == l].x , 
                    plotting_X[labels == l].y, 
                    c=c, label=l, s=10)
    plt.legend()
    plt.grid()
    plt.tight_layout()

# %%
# Hierarchical Clustering
Z = linkage(train_vecs, 'ward')
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
# 5 truncated
plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index or (cluster size)')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=5,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %%
# 7 truncated
plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index or (cluster size)')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=7,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %%
plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index or (cluster size)')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=10,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %%
def plot_clustering(X, labels, title=None):
    plt.figure(figsize=(6, 4))
    for i in range(X.shape[0]):
        plt.scatter(X[i, 0], X[i, 1], color=plt.cm.spectral(labels[i] / 10.))

    plt.xticks([])
    plt.yticks([])
    if title is not None:
        plt.title(title, size=17)
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
# 降維(PCA)至二維
pca = decomposition.PCA(n_components=2)
X1= pca.fit_transform(train_vecs)

# %%
# 降維(SpectralEmbedding, non-linear)至二維
X2 = manifold.SpectralEmbedding(n_components=2).fit_transform(train_vecs)

# %%
# 降維(t-SNE, non-linear)至二維
X3 = manifold.TSNE(n_components=2).fit_transform(train_vecs)

# %%
# K-Mean(PCA)
plot_clustering(X1, All_kmeans.labels_, "K-Mean")

# %%
plot_clustering(X1, kmean_7.labels_, "K-Mean")

# %%
# K-Mean(t-SNE)
plot_clustering(X3, All_kmeans.labels_, "K-Mean")

# %%
# Hierarchical Clustering
Hclustering = AgglomerativeClustering(n_clusters=5,
 affinity="euclidean", linkage="ward")

# %%
HC = Hclustering.fit(train_vecs)

# %%
# PCA
plot_clustering(X1, HC.labels_, "ward")

# %%
# SpectralEmbedding
plot_clustering(X2, HC.labels_, "ward")

# %%
# t-SNE
plot_clustering(X3, HC.labels_, "ward")

# %%
X.insert(1, "Cluster2", HC.labels_)

# %%
X['Cluster2'].value_counts()
# Out:
# 2    1970
# 0    1451
# 1     554
# 4     380
# 3      62
# Name: Cluster2, dtype: int64

# %%
grouped2 = X["lable"].groupby(X['Cluster2'])
grouped2.all()
# Out:
# Cluster2
# 0                  {'租金問題'}
# 1            {'糾紛', '租金問題'}
# 2                  {'房屋問題'}
# 3                    {None}
# 4    {'糾紛', '合約問題', '租金問題'}
# Name: lable, dtype: object

# %%
# Hierarchical Clustering group=(5, 10), different linkage_method, connectivity (PCA)
knn_graph = kneighbors_graph(X1, 30, include_self=False)
for connectivity in (None, knn_graph):
    for n_clusters in (10, 5):
        plt.figure(figsize=(10, 5))
        for index, linkage_method in enumerate(('average', 'complete', 'ward')):
            plt.subplot(1, 3, index + 1)
            model = AgglomerativeClustering(linkage=linkage_method,
                                            connectivity=connectivity,
                                            n_clusters=n_clusters)
            t0 = time.time()
            model.fit(train_vecs)
            elapsed_time = time.time() - t0
            plt.scatter(X1[:, 0], X1[:, 1], c=model.labels_,
                        cmap=plt.cm.spectral)
            plt.title('linkage=%s (time %.2fs)' % (linkage_method, elapsed_time),
                      fontdict=dict(verticalalignment='top'))
            plt.axis('equal')
            plt.axis('off')

            plt.subplots_adjust(bottom=0, top=.89, wspace=0,
                                left=0, right=1)
            plt.suptitle('n_cluster=%i, connectivity=%r' %
                         (n_clusters, connectivity is not None), size=17)


plt.show()

# %%
# Hierarchical Clustering group=(5, 10), different linkage_method, connectivity (t-SNE)
knn_graph = kneighbors_graph(X3, 30, include_self=False)
for connectivity in (None, knn_graph):
    for n_clusters in (10, 5):
        plt.figure(figsize=(10, 5))
        for index, linkage_method in enumerate(('average', 'complete', 'ward')):
            plt.subplot(1, 3, index + 1)
            model = AgglomerativeClustering(linkage=linkage_method,
                                            connectivity=connectivity,
                                            n_clusters=n_clusters)
            t0 = time.time()
            model.fit(train_vecs)
            elapsed_time = time.time() - t0
            plt.scatter(X3[:, 0], X3[:, 1], c=model.labels_,
                        cmap=plt.cm.spectral)
            plt.title('linkage=%s (time %.2fs)' % (linkage_method, elapsed_time),
                      fontdict=dict(verticalalignment='top'))
            plt.axis('equal')
            plt.axis('off')

            plt.subplots_adjust(bottom=0, top=.89, wspace=0,
                                left=0, right=1)
            plt.suptitle('n_cluster=%i, connectivity=%r' %
                         (n_clusters, connectivity is not None), size=17)


plt.show()

# %%
bandwidth = estimate_bandwidth(train_vecs, quantile=0.2, n_samples=500)
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(train_vecs)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)
print("number of estimated clusters : %d" % n_clusters_)
colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X1[my_members, 0], X1[my_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
plt.title('MeanShift')
plt.show()
# Out:
# number of estimated clusters : 1

# %%
# X.insert(2, "Cluster3", ms.labels_)
# X['Cluster3'].value_counts()
# Out:
# 0    4209
# 1     156
# 2      45
# 3       6
# 4       1
# Name: Cluster3, dtype: int64

# %%
# grouped3 = X["lable"].groupby(X['Cluster3'])
# grouped3.all()
# Out:
# Cluster3
# 0                    {'糾紛', '租金問題'}
# 1                          {'租金問題'}
# 2                          {'租金問題'}
# 3                            {'糾紛'}
# 4    {'糾紛', '房屋問題', '合約問題', '租金問題'}
# Name: lable, dtype: object

# %%
# birch
n_clusters = 5
birch = Birch(n_clusters=n_clusters)
birch.fit_transform(train_vecs)
plot_clustering(X1, birch.labels_, "birch")

# %%
X.insert(2, "Cluster3", birch.labels_)
X['Cluster3'].value_counts()
# Out:
# 2    1970
# 0    1451
# 1     554
# 4     380
# 3      62
# Name: Cluster3, dtype: int64

# %%
grouped3 = X["lable"].groupby(X['Cluster3'])
grouped3.all()
# Out:
# Cluster3
# 0                  {'租金問題'}
# 1            {'糾紛', '租金問題'}
# 2                  {'房屋問題'}
# 3                    {None}
# 4    {'糾紛', '合約問題', '租金問題'}
# Name: lable, dtype: object

# %%
Hclustering_10 = AgglomerativeClustering(n_clusters=10,
 affinity="euclidean", linkage="ward")
HC_10 = Hclustering_10.fit(train_vecs)

# %%
plot_clustering(X2, HC_10.labels_, "ward")

# %%
X.insert(3, "Cluster4", HC_10.labels_)
X['Cluster4'].value_counts()
# Out:
# 7    1515
# 5     701
# 9     548
# 4     455
# 2     358
# 8     230
# 0     202
# 6     196
# 3     150
# 1      62
# Name: Cluster4, dtype: int64

# %%
grouped4 = X["lable"].groupby(X['Cluster4'])
grouped4.all()
# Out:
# Cluster4
# 0    {'治安', '合約問題', '租金問題'}
# 1                    {None}
# 2            {'糾紛', '租金問題'}
# 3    {'糾紛', '合約問題', '租金問題'}
# 4          {'房屋問題', '租金問題'}
# 5                  {'租金問題'}
# 6                  {'租金問題'}
# 7                  {'房屋問題'}
# 8          {'環境問題', '合約問題'}
# 9                  {'租金問題'}
# Name: lable, dtype: object

# %%
X.insert(4, "Cluster5", kmean_7.labels_)
X['Cluster5'].value_counts()
# Out:
# 4    1257
# 6    1085
# 0     559
# 1     552
# 5     507
# 2     455
# 3       2
# Name: Cluster5, dtype: int64

# %%
grouped4 = X["lable"].groupby(X['Cluster5'])
grouped4.all()
# Out:
# Cluster5
# 0    {'糾紛', '合約問題', '租金問題'}
# 1                  {'房屋問題'}
# 2            {'糾紛', '租金問題'}
# 3                    {None}
# 4          {'合約問題', '租金問題'}
# 5                    {None}
# 6                  {'租金問題'}
# Name: lable, dtype: object

# %%
from matplotlib.ticker import NullFormatter

# %%
n_neighbors = 10
n_components = 2
fig = plt.figure(figsize=(15, 8))
plt.suptitle("Manifold Learning with %i neighbors"
             % (n_neighbors), fontsize=14)

t0 = time.time()
Y = manifold.Isomap(n_neighbors, n_components).fit_transform(train_vecs)
t1 = time.time()
print("Isomap: %.2g sec" % (t1 - t0))
ax = fig.add_subplot(257)
plt.scatter(Y[:, 0], Y[:, 1], c=color, cmap=plt.cm.Spectral)
plt.title("Isomap (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')


t0 = time.time()
mds = manifold.MDS(n_components, max_iter=100, n_init=1)
Y = mds.fit_transform(train_vecs)
t1 = time.time()
print("MDS: %.2g sec" % (t1 - t0))
ax = fig.add_subplot(258)
plt.scatter(Y[:, 0], Y[:, 1], c=color, cmap=plt.cm.Spectral)
plt.title("MDS (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')


t0 = time.time()
se = manifold.SpectralEmbedding(n_components=n_components,
                                n_neighbors=n_neighbors)
Y = se.fit_transform(train_vecs)
t1 = time.time()
print("SpectralEmbedding: %.2g sec" % (t1 - t0))
ax = fig.add_subplot(259)
plt.scatter(Y[:, 0], Y[:, 1], c=color, cmap=plt.cm.Spectral)
plt.title("SpectralEmbedding (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

t0 = time.time()
tsne = manifold.TSNE(n_components=n_components, init='pca', random_state=0)
Y = tsne.fit_transform(train_vecs)
t1 = time.time()
print("t-SNE: %.2g sec" % (t1 - t0))
ax = fig.add_subplot(2, 5, 10)
plt.scatter(Y[:, 0], Y[:, 1], c=color, cmap=plt.cm.Spectral)
plt.title("t-SNE (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

plt.show()
# Out:
# Isomap: 60 sec
# MDS: 48 sec
# SpectralEmbedding: 29 sec
# t-SNE: 49 sec
